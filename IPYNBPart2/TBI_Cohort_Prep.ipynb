# %%
TBI_EPI_MED_cohort = spark.read.parquet("file:/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/TBI_EPI_Med_Final.parquet")

# %%
TBI_EPI_MED_cohort.createOrReplaceTempView('TBI_EPI_MED_table')

# %%
TBI_EPI_MED_cohort.printSchema()

# %%
TBI_EPI_MED_result = spark.sql("SELECT COUNT(DISTINCT (personid)) FROM TBI_EPI_MED_table")
TBI_EPI_MED_result.show()
# Out:
# +------------------------+
# |count(DISTINCT personid)|
# +------------------------+
# |                 2254545|
# +------------------------+
