# %%
import shutil

# Specify the source and destination directory paths
# source_directory = '/home/o_suchsi/work/Oklahoma State/Zheng_Han/medication_s.parquet'
# destination_directory = '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/medication_s.parquet'
source_directory = '/home/z_han/work/Oklahoma State/Zheng_Han/epilepsy/priya-bigjoin'
destination_directory = '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/priya-bigjoin.parquet'

# Copy the entire source directory and its contents to the destination directory
shutil.copytree(source_directory, destination_directory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0c89fa84bea4> in <module>
#       8
#       9 # Copy the entire source directory and its contents to the destination directory
# ---> 10 shutil.copytree(source_directory, destination_directory)
#
# /opt/conda/lib/python3.7/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks)
#     316
#     317     """
# --> 318     names = os.listdir(src)
#     319     if ignore is not None:
#     320         ignored_names = ignore(src, names)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/z_han/work/Oklahoma State/Zheng_Han/epilepsy/priya-bigjoin'

# %%
# Delete the Target directory
import shutil
import os

# source_directory = '/home/o_suchsi/work/Oklahoma State/Zheng_Han/epilepsy'
destination_directory = '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Epilepsy_Control_CorrectedDate'

# Delete the existing destination directory
if os.path.exists(destination_directory):
    shutil.rmtree(destination_directory)

# # Copy the source directory to the destination
# shutil.copytree(source_directory, destination_directory)

# %%
if [ -d "/home/o_suchsi/work/Oklahoma State/Priya" ]; then
  echo "Directory exists"
else
  echo "Directory does not exist or is not valid"
fi
# Out:
#   File "<ipython-input-7-397685deef06>", line 1
#     if [ -d "/home/o_suchsi/work/Oklahoma State/Priya" ]; then
#                                                      ^
# SyntaxError: invalid syntax

# %%
if [ -d "/home/o_suchsi/work/Oklahoma State/Zheng_Han/epilepsy" ]; then
  echo "Directory exists"
else
  echo "Directory does not exist or is not valid"
fi
# Out:
#   File "<ipython-input-6-db6a1ba32b60>", line 1
#     if [ -d "/home/o_suchsi/work/Oklahoma State/Zheng_Han/epilepsy" ]; then
#                                                                   ^
# SyntaxError: invalid syntax

# %%
import shutil
import os

# source_directory = '/home/o_suchsi/work/Oklahoma State/Normalization_Medication_Cohort_control_Stack.ipynb'
# destination_directory = '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/'
source_directory = '/home/o_suchsi/work/Oklahoma State/Zheng_Han/epilepsy/priya_control_lab_pivot'
destination_directory = '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/priya_control_lab_pivot'
# Ensure the destination directory exists
os.makedirs(destination_directory, exist_ok=True)

# Copy all files from the source directory to the destination directory
for filename in os.listdir(source_directory):
    source_file = os.path.join(source_directory, filename)
    destination_file = os.path.join(destination_directory, filename)
    shutil.copy2(source_file, destination_file)
