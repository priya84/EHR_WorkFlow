# %%
import shutil

# source_file = '/home/o_suchsi/work/Oklahoma State/Zheng_Han/epilepsy/medication_s.parquet'
# destination_file = '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy'
source_file = '/home/o_suchsi/work/Oklahoma State/Zheng_Han/epilepsy/priya_control_lab_pivot'
destination_file = '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy'

# Copy the file from the source location to the destination location
shutil.copy2(source_file, destination_file)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-3-d89f9f203308> in <module>
#       7
#       8 # Copy the file from the source location to the destination location
# ----> 9 shutil.copy2(source_file, destination_file)
#
# /opt/conda/lib/python3.7/shutil.py in copy2(src, dst, follow_symlinks)
#     264     if os.path.isdir(dst):
#     265         dst = os.path.join(dst, os.path.basename(src))
# --> 266     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     267     copystat(src, dst, follow_symlinks=follow_symlinks)
#     268     return dst
#
# /opt/conda/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# ...

# %%
import shutil

source_file = '/home/o_suchsi/work/SuperSet-Cohort+ControlVersion4.ipynb'
# source_file = '/home/z_han/work/Oklahoma State/Zheng_Han/epilepsy/priya-bigjoin.ipynb'
destination_file =  '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/'

# Copy the file from the source location to the destination location
shutil.copy2(source_file, destination_file)
# Out:
# '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/SuperSet-Cohort+ControlVersion4.ipynb'

# %%
import shutil
import os

# List of source files to copy
source_files = [
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/AED_med-Copy1.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/AED_med.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization commo for control.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization_Extension2_Lab.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization_FinalCleanUp_Commorbidity_Cohort_Control.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization_Medication_API_ClassName.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization_Medication_Cohort_control_Stack.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization_Medication_Cohort_Control_StackLatest.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/NormalizationLab_Finalized.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalized_Commorbidity_Codes_Final.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Predictions.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/priya-control-pivot.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/RearrangeColumns.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Smallset.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Strat_balance_sampling.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/TBI_Cohort_Prep.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/TBI_EPI_Cohort_Combination.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/TBI_EPI_Extract.ipynb',
    '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/test.ipynb'
]

# Destination directory
destination_dir = '/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/FilePart4/'

# Ensure the destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Loop through each file and copy it to the destination
for source_file in source_files:
    if os.path.isfile(source_file):  # Check if the file exists
        shutil.copy2(source_file, destination_dir)
        print(f"Copied: {source_file} → {destination_dir}")
    else:
        print(f"File not found: {source_file}")
# Out:
# Copied: /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/AED_med-Copy1.ipynb → /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/FilePart4/
# Copied: /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/AED_med.ipynb → /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/FilePart4/
# Copied: /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization commo for control.ipynb → /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/FilePart4/
# Copied: /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization_Extension2_Lab.ipynb → /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/FilePart4/
# Copied: /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization_FinalCleanUp_Commorbidity_Cohort_Control.ipynb → /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/FilePart4/
# Copied: /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/Normalization_Medication_API_ClassName.ipynb → /home/o_suchsi/work/Oklahoma State/Priya/epilepsy/FilePart4/
# ...
