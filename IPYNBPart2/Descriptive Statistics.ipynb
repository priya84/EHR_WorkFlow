# %%
import pandas as pd
import pandasql as ps
import pixiedust
import sys
sys.path.append('..')
import util
import etl
import pyarrow.parquet as pq
import pyarrow as pa
# !pip install duckdb
import duckdb

util.usedatabase(spark, "real_world_data_jun_2022")

pixiedust.enableJobMonitor()

con = duckdb.connect()
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.19</span>
#         </div>
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# Using real_world_data_jun_2022 ....
# Successfully enabled Spark Job Progress Monitor

# %%
TBI_EPI_Cohort_PersonId_Final = spark.read.parquet('file:/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/TBI_EPI_Cohort_Final_V1')
# Out:
# <div id="pm_overallContainer36f447fa" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie36f447fa" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName36f447fa"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress36f447fa" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container36f447fa" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors36f447fa">
#     </ul>
#     <div class="tab-content" id="tabContent36f447fa">
#     </div>
# </div>
#
# <script>
# $("#twistie36f447fa").click(function(){
#     visible = $("#pm_container36f447fa").is(':visible');
#     $("#pm_container36f447fa").slideToggle("slow");
# ...

# %%
TBI_EPI_Cohort_PersonId_Final.printSchema()
# Out:
# <div id="pm_overallContainer2ce5cad3" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie2ce5cad3" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName2ce5cad3"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress2ce5cad3" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container2ce5cad3" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors2ce5cad3">
#     </ul>
#     <div class="tab-content" id="tabContent2ce5cad3">
#     </div>
# </div>
#
# <script>
# $("#twistie2ce5cad3").click(function(){
#     visible = $("#pm_container2ce5cad3").is(':visible');
#     $("#pm_container2ce5cad3").slideToggle("slow");
# ...

# %%
TBI_EPI_Cohort_PersonId_Final.createOrReplaceTempView('TBI_EPI')
# Out:
# <div id="pm_overallContainerdef01bf1" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistiedef01bf1" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamedef01bf1"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressdef01bf1" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerdef01bf1" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsdef01bf1">
#     </ul>
#     <div class="tab-content" id="tabContentdef01bf1">
#     </div>
# </div>
#
# <script>
# $("#twistiedef01bf1").click(function(){
#     visible = $("#pm_containerdef01bf1").is(':visible');
#     $("#pm_containerdef01bf1").slideToggle("slow");
# ...

# %%
TBI_with_EPI_all = spark.sql("SELECT DISTINCT personid, COUNT(*) AS count FROM TBI_EPI GROUP BY personid HAVING count > 1")
TBI_with_EPI_all.show(5, truncate = False)
# Out:
# <div id="pm_overallContainered6c6aee" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistieed6c6aee" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNameed6c6aee"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressed6c6aee" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containered6c6aee" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsed6c6aee">
#     </ul>
#     <div class="tab-content" id="tabContented6c6aee">
#     </div>
# </div>
#
# <script>
# $("#twistieed6c6aee").click(function(){
#     visible = $("#pm_containered6c6aee").is(':visible');
#     $("#pm_containered6c6aee").slideToggle("slow");
# ...

# %%
TBI_with_EPI_pid = spark.sql("SELECT * FROM TBI_EPI where personid ='06b4a13d-ca4a-4111-89bb-07507ff5d0f8'")
TBI_with_EPI_pid.show(5, truncate = False)
# Out:
# <div id="pm_overallContainer29d0304f" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie29d0304f" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName29d0304f"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress29d0304f" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container29d0304f" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors29d0304f">
#     </ul>
#     <div class="tab-content" id="tabContent29d0304f">
#     </div>
# </div>
#
# <script>
# $("#twistie29d0304f").click(function(){
#     visible = $("#pm_container29d0304f").is(':visible');
#     $("#pm_container29d0304f").slideToggle("slow");
# ...

# %%
cohort_demo = etl.extractDemo(spark,TBI_EPI_Cohort_PersonId_Final,outputfilename="cohort_demo_Final_v1", outputfolder = "Priya/epilepsy")
# Out:
# <div id="pm_overallContainer052c44bf" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie052c44bf" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName052c44bf"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress052c44bf" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container052c44bf" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors052c44bf">
#     </ul>
#     <div class="tab-content" id="tabContent052c44bf">
#     </div>
# </div>
#
# <script>
# $("#twistie052c44bf").click(function(){
#     visible = $("#pm_container052c44bf").is(':visible');
#     $("#pm_container052c44bf").slideToggle("slow");
# ...

# %%
cohort_demo = spark.read.parquet('file:/home/o_suchsi/work/Oklahoma State/Priya/epilepsy/cohort_demo_Final_v1')
# Out:
# <div id="pm_overallContainer1e410cbf" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie1e410cbf" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName1e410cbf"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress1e410cbf" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container1e410cbf" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors1e410cbf">
#     </ul>
#     <div class="tab-content" id="tabContent1e410cbf">
#     </div>
# </div>
#
# <script>
# $("#twistie1e410cbf").click(function(){
#     visible = $("#pm_container1e410cbf").is(':visible');
#     $("#pm_container1e410cbf").slideToggle("slow");
# ...

# %%
from pyspark.sql.functions import *
demo_processed = etl.process_demo(spark, TBI_EPI_Cohort_PersonId_Final, cohort_demo)
# Out:
# <div id="pm_overallContainer9e81fea0" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie9e81fea0" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName9e81fea0"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress9e81fea0" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container9e81fea0" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors9e81fea0">
#     </ul>
#     <div class="tab-content" id="tabContent9e81fea0">
#     </div>
# </div>
#
# <script>
# $("#twistie9e81fea0").click(function(){
#     visible = $("#pm_container9e81fea0").is(':visible');
#     $("#pm_container9e81fea0").slideToggle("slow");
# ...

# %%
demo_processed.printSchema()
# Out:
# <div id="pm_overallContainer6f698989" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie6f698989" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName6f698989"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress6f698989" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container6f698989" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors6f698989">
#     </ul>
#     <div class="tab-content" id="tabContent6f698989">
#     </div>
# </div>
#
# <script>
# $("#twistie6f698989").click(function(){
#     visible = $("#pm_container6f698989").is(':visible');
#     $("#pm_container6f698989").slideToggle("slow");
# ...

# %%
demo_processed.createOrReplaceTempView('Epilepsy_Cohort_Domo')
# Out:
# <div id="pm_overallContainerc4285d09" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistiec4285d09" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamec4285d09"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressc4285d09" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerc4285d09" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsc4285d09">
#     </ul>
#     <div class="tab-content" id="tabContentc4285d09">
#     </div>
# </div>
#
# <script>
# $("#twistiec4285d09").click(function(){
#     visible = $("#pm_containerc4285d09").is(':visible');
#     $("#pm_containerc4285d09").slideToggle("slow");
# ...

# %%
Demo_Result = spark.sql("SELECT * FROM Epilepsy_Cohort_Domo where personid ='06b4a13d-ca4a-4111-89bb-07507ff5d0f8'")
Demo_Result.show(5, truncate = False)
# Out:
# <div id="pm_overallContainer3e391c5b" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie3e391c5b" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName3e391c5b"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress3e391c5b" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container3e391c5b" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors3e391c5b">
#     </ul>
#     <div class="tab-content" id="tabContent3e391c5b">
#     </div>
# </div>
#
# <script>
# $("#twistie3e391c5b").click(function(){
#     visible = $("#pm_container3e391c5b").is(':visible');
#     $("#pm_container3e391c5b").slideToggle("slow");
# ...

# %%
Demo_Result_1 = spark.sql("SELECT personid, COUNT(*) AS count FROM Epilepsy_Cohort_Domo GROUP BY personid HAVING count > 1")
Demo_Result_1.show(5, truncate = False)
# Out:
# <div id="pm_overallContainerab0e4480" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistieab0e4480" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNameab0e4480"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressab0e4480" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerab0e4480" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsab0e4480">
#     </ul>
#     <div class="tab-content" id="tabContentab0e4480">
#     </div>
# </div>
#
# <script>
# $("#twistieab0e4480").click(function(){
#     visible = $("#pm_containerab0e4480").is(':visible');
#     $("#pm_containerab0e4480").slideToggle("slow");
# ...

# %%
Demo_Result = spark.sql("SELECT * FROM Epilepsy_Cohort_Domo where personid ='0002b0ab-d9ba-4957-b310-5e1e375dd3c2'")
Demo_Result.show(33, truncate = False)
# Out:
# <div id="pm_overallContainerf7320977" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistief7320977" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamef7320977"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressf7320977" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerf7320977" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsf7320977">
#     </ul>
#     <div class="tab-content" id="tabContentf7320977">
#     </div>
# </div>
#
# <script>
# $("#twistief7320977").click(function(){
#     visible = $("#pm_containerf7320977").is(':visible');
#     $("#pm_containerf7320977").slideToggle("slow");
# ...

# %%
Demo_Result = spark.sql("SELECT * FROM Epilepsy_Cohort_Domo where personid ='0002b0ab-d9ba-4957-b310-5e1e375dd3c2'")
Demo_Result.show(33, truncate = False)

# %%
Demo_Result_2 = spark.sql("SELECT personid, COUNT (DISTINCT (gender)) AS count_gender FROM Epilepsy_Cohort_Domo GROUP BY personid HAVING COUNT (DISTINCT (gender)) > 1")
Demo_Result_2.show(5, truncate = False)
# Out:
# <div id="pm_overallContainer535626b9" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie535626b9" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName535626b9"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress535626b9" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container535626b9" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors535626b9">
#     </ul>
#     <div class="tab-content" id="tabContent535626b9">
#     </div>
# </div>
#
# <script>
# $("#twistie535626b9").click(function(){
#     visible = $("#pm_container535626b9").is(':visible');
#     $("#pm_container535626b9").slideToggle("slow");
# ...

# %%
Demo_Result_3 = spark.sql("SELECT * FROM Epilepsy_Cohort_Domo where personid ='001dcb8c-6b9e-4209-8e64-0d5986baddd8'")
Demo_Result_3.show(2, truncate = False)
# Out:
# <div id="pm_overallContainer044d2092" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie044d2092" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName044d2092"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress044d2092" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container044d2092" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors044d2092">
#     </ul>
#     <div class="tab-content" id="tabContent044d2092">
#     </div>
# </div>
#
# <script>
# $("#twistie044d2092").click(function(){
#     visible = $("#pm_container044d2092").is(':visible');
#     $("#pm_container044d2092").slideToggle("slow");
# ...

# %%
Demo_Result_5 = spark.sql("SELECT personid, COUNT (DISTINCT (race)) AS count_race FROM Epilepsy_Cohort_Domo GROUP BY personid HAVING COUNT (DISTINCT (race)) > 1")
Demo_Result_5.show(5, truncate = False)
# Out:
# <div id="pm_overallContainer5f63f923" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie5f63f923" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName5f63f923"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress5f63f923" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container5f63f923" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors5f63f923">
#     </ul>
#     <div class="tab-content" id="tabContent5f63f923">
#     </div>
# </div>
#
# <script>
# $("#twistie5f63f923").click(function(){
#     visible = $("#pm_container5f63f923").is(':visible');
#     $("#pm_container5f63f923").slideToggle("slow");
# ...

# %%
Demo = spark.sql("SELECT * FROM Demographics where personid = '001dcb8c-6b9e-4209-8e64-0d5986baddd8'")
Demo.show(2, truncate = False)
# Out:
# <div id="pm_overallContainer3fae901b" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie3fae901b" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName3fae901b"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress3fae901b" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container3fae901b" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors3fae901b">
#     </ul>
#     <div class="tab-content" id="tabContent3fae901b">
#     </div>
# </div>
#
# <script>
# $("#twistie3fae901b").click(function(){
#     visible = $("#pm_container3fae901b").is(':visible');
#     $("#pm_container3fae901b").slideToggle("slow");
# ...

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.getOrCreate()

# Set the database and table names
database_name = "real_world_data_jun_2022"
table_name = "lab"

# Use the database
spark.sql(f"USE {database_name}")

# Get the table schema
table_schema = spark.sql(f"DESCRIBE {table_name}")

# Extract the field names
field_names = [row.col_name for row in table_schema.collect()]

# Print the field names
for field_name in field_names:
    print(field_name)

# %%
dementia_demo_d =spark.sql("""
select *
from dedupedemographics
""")
# Out:
# <div id="pm_overallContainerf7f4e6c6" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistief7f4e6c6" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamef7f4e6c6"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressf7f4e6c6" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerf7f4e6c6" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsf7f4e6c6">
#     </ul>
#     <div class="tab-content" id="tabContentf7f4e6c6">
#     </div>
# </div>
#
# <script>
# $("#twistief7f4e6c6").click(function(){
#     visible = $("#pm_containerf7f4e6c6").is(':visible');
#     $("#pm_containerf7f4e6c6").slideToggle("slow");
# ...

# %%
##Edited bysai testing
from pyspark.sql.functions import col
from pyspark.sql.types import DateType
# Extract the date using regexp_extract
extracted_date_df_1 = dementia_demo_d.withColumn("gender", col("gender.value")).withColumn("birthdate", col("birthdate.value").cast(DateType())).withColumn("race", col("race.value"))
# Out:
# <div id="pm_overallContainerc5eca9af" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistiec5eca9af" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamec5eca9af"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressc5eca9af" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerc5eca9af" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsc5eca9af">
#     </ul>
#     <div class="tab-content" id="tabContentc5eca9af">
#     </div>
# </div>
#
# <script>
# $("#twistiec5eca9af").click(function(){
#     visible = $("#pm_containerc5eca9af").is(':visible');
#     $("#pm_containerc5eca9af").slideToggle("slow");
# ...

# %%
extracted_date_df_1.createOrReplaceTempView('aa')
dementia_demo =spark.sql("""
select distinct l.personid, l.birthdate, l.gender,l.race
from
aa l
""")
# Out:
# <div id="pm_overallContainerf8423038" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistief8423038" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamef8423038"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressf8423038" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerf8423038" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsf8423038">
#     </ul>
#     <div class="tab-content" id="tabContentf8423038">
#     </div>
# </div>
#
# <script>
# $("#twistief8423038").click(function(){
#     visible = $("#pm_containerf8423038").is(':visible');
#     $("#pm_containerf8423038").slideToggle("slow");
# ...

# %%
dementia_demo.createOrReplaceTempView('bb')
df_duplicates=spark.sql("""
select c.personid from bb c
where c.personid = '0000cad3-49d1-43cd-9cb7-e5b9ed9fd94a'
""")
df_duplicates.show(2, truncate=False)
# Out:
# <div id="pm_overallContainer9a6bd7f8" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie9a6bd7f8" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName9a6bd7f8"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress9a6bd7f8" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container9a6bd7f8" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors9a6bd7f8">
#     </ul>
#     <div class="tab-content" id="tabContent9a6bd7f8">
#     </div>
# </div>
#
# <script>
# $("#twistie9a6bd7f8").click(function(){
#     visible = $("#pm_container9a6bd7f8").is(':visible');
#     $("#pm_container9a6bd7f8").slideToggle("slow");
# ...
